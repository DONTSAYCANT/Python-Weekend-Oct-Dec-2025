# %%
#String:

sequence of char
collection of char
" " or ' '

"python" ===> "p" "y" "t" "h" "o" "n"

#index values

#Forward indexing starts with 0 from first char
#reverse indexing #starts with -1 from last char


#Indexing


#Slicing: extracting sub string from a string


#() ==> function call
#[] ==> indexing and slicing

# %%
#{} ==> format and fstring
#[] ==> indexing and slicing 


var = "computer_science"


print(var[0])
print(var[1])
print(var[2])
print(var[10])
print(var[-2])
print(var[-12])
print(var[6])
print(var[8])
print(var[19])
# Out:
# c
# o
# m
# c
# c
# u
# e
# _
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12700\524460143.py in <module>
#      14 print(var[6])
#      15 print(var[8])
# ---> 16 print(var[19])
#
# IndexError: string index out of range

# %%
#string : 

collection of chars
" " ' '

Character: single letter

# %%
a = "hello"
print(a)

print(a[0])

print(a[-3])
# Out:
# hello
# h
# l

# %%
var = "python_interpreter"

print(var)
print(var[0])
print(var[-1])
print(var[8])
print(var[9])
print(var[-5])
# Out:
# python_interpreter
# p
# r
# n
# t
# r

# %%
var = "computer_science"

print(var)
print(var[0])
print(var[-1])
print(var[8])
print(var[9])
print(var[-5])
# Out:
# computer_science
# c
# e
# _
# s
# i

# %%
a = "python" #indexing

print(a)

print(a[0]) #p

print(a[3]) #h

print(a[-1]) #n

print(a[-4]) #t
# Out:
# python
# p
# h
# n
# t

# %%
a = "mathematics"

# %% [markdown]
# ## String Slicing

# %%
#

#[starting index (including): end index (exclude) : index interval (default = 1, option)]

# %%
a = "computer_science"


print(a[1:5]) #1,2,3,4
print(a[0:4])
print(a[0:8])
print(a[9:17])
# Out:
# ompu
# comp
# computer
# science

# %%
#Type 1

#starting index / ending index (both available or any one available or both unavailable)
#index interval not available
#extract string in only forward manner

a = "computer_science"

print(a[3:8])
print(a[5:-5])
print(a[-12:-7])
print(a[-10:15])
print(a[:6])
print(a[:-7])
print(a[5:])
print(a[-10:])
print(a[:])
print(a[4:100])
print(a[12:5]) #empty  print(a[12:5:1])
# Out:
# puter
# ter_sc
# uter_
# er_scienc
# comput
# computer_
# ter_science
# er_science
# computer_science
# uter_science

# %%
puter
ter_sc
uter_
er_scienc
comput
computer_
ter_science
er_science
computer_science
uter_science
empty

# %%
a = "computer_science"


print(a[4:100])
print(a[100]) #error for unavailable index
# Out:
# uter_science
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-4b30b836a82b> in <module>
#       3
#       4 print(a[4:100])
# ----> 5 print(a[100])
#
# IndexError: string index out of range

# %%
a = "computer_science"

print(a[-20:])
# Out:
# computer_science

# %%
#rule


print(a[-20:]) #slicing #no error
print(a[-20]) #indexing
# Out:
# computer_science
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-29116267dd5c> in <module>
#       3
#       4 print(a[-20:]) #slicing #no error
# ----> 5 print(a[-20]) #indexing
#
# IndexError: string index out of range

# %%
a = "python_program"

print(a[3:8]) #hon_p
print(a[5:-3]) #n_prog
print(a[2:-2]) #thon_progr
print(a[-1:-9]) #empty
print(a[:-2]) #python_progr
print(a[-2:]) #am
print(a[5:]) #n_program
print(a[:5]) #
print(a[:])
print(a[2:200])
print(a[-2:200])

# %%
## Type2

#starting index and ending index (both available or any one available or both unavailable)
#index interval should be available (only positive index interval)
#extract string in only forward manner


val = "computer_science"

print(val[3:10]) #type1
print(val[3:10:1])
print(val[3:10:2])
print(val[3:10:3])
print(val[5:-5:1])
print(val[5:-5:2])
print(val[5:-5:5])
print(val[:8:4])
print(val[5::3])
print(val[::2])
print(val[12:5:3])
# Out:
# puter_s
# puter_s
# ptrs
# pes
# ter_sc
# trs
# tc
# cu
# t_ic
# cmue_cec

# %%
puter_s
puter_s
ptrs
pes
ter_sc
trs
tc
cu
t_ic
cmue_cec
empty

# %%
#type 3

#all the three values (starting index, ending index, index interval) are values
#you can have positive/negative (starting index, ending index, index interval) 
#extract in forward and reverse manner

#FWD (start to end) + Pos(index) ===> output
#REV (start to end) + Neg(index) ==> output
#FWD (start to end) + Neg(index) ==> empty
#REV (start to end) + Pos(index) ==> empty

#Direction for starting index to end index
#sign in index interval

a = "computer_science"

print(a[2:-2:2])
print(a[2:-2:-2])
print(a[-2:2:2])
print(a[-2:2:-2])
print(a[3:-3:3])
print(a[3:-3:-3])
print(a[-3:3:3])
print(a[-3:3:-3])
# Out:
# mue_ce
#
#
# cec_eu
# pese
#
#
# ncru

# %%
mue_ce
empty
empty
cec_eu
pese
empty
empty
ncru

# %%
#Type 4  (No empty output)

#index interval should be there
#starting index or ending index or both are not available
#you can have positive/negative (starting index, ending index, index interval) 
#extract in forward and reverse manner

#FWD (start to end) + Pos(index) ===> output
#REV (start to end) + Neg(index) ==> output


#Direction for starting index to end index
#sign in index interval

print(a[6::3])
print(a[6::-3])
print(a[:8:3])
print(a[:8:-3])
print(a[2::5])
print(a[10::-5])
print(a[:6:1])
print(a[:7:-2])
# Out:
# esee
# epc
# cpe
# ees
# mre
# ctc
# comput
# enis

# %%
esee
epc
cpe
ees
mre
ctc
comput
enis

# %%
#Type 5

print(a[::1])
print(a[::2])
print(a[::3])
print(a[::-1])
print(a[::-2])
print(a[::-3])
# Out:
# computer_science
# cmue_cec
# cpesee
# ecneics_retupmoc
# enisrtpo
# eesepc

# %%
Get one string from user
identify the middle character of the string


october

august

len // 2

# %%
input_string = input("Please enter a string: ")

length_string_center = len(input_string) // 2

length_string_center = int(len(input_string) / 2)

print("The middle character is ",input_string[length_string_center])
# Out:
# Please enter a string: karthik
# The middle character is  t

# %%
string1 = "meghala 12.19"

output = float(string1.split()[1])

print(output)
print(type(output))
# Out:
# 12.19
# <class 'float'>

# %%
#collect two strings from user

"""
string1: python
String2: java

output ===> jythonpava64hv

string1: maths
string2: science

output ===> sathsmcience57te
"""

string1 = "maths"
string2 = "science"


print(string1[0])
print(string2[0])

print(string1[1:])
print(string2[1:])


print(string2[0] + string1[1:] + string1[0] + string1[1:] + str(len(string1)) + str(len(string2)) + string1[len(string1)//2] + string2[len(string2)//2])
# Out:
# m
# s
# aths
# cience
# sathsmaths57te
